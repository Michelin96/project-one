# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file_one = "Resources/NBA_Valuations.csv"

file_one_df = pd.read_csv(file_one)
file_one_df.head(20)

new_file_one_df = file_one_df.drop(columns=["Team.1","Team.2", "Team.3", "Team.4"], axis=1)

renamed_file_one_df = new_file_one_df.rename(columns={"2015 Value": "2015", "2016 Value": "2016", "2017 Value": "2017", "2018 Value": "2018", "2019 Value": "2019"})
renamed_file_one_df
# Out:
#               Team              2015                 2016  \
# 0           Lakers  2,600,000,000.00   $3,000,000,000.00
# 1           Knicks  2,500,000,000.00   $2,700,000,000.00
# 2            Bulls  2,000,000,000.00   $2,300,000,000.00
# 3          Celtics  1,700,000,000.00   $2,100,000,000.00
# 4         Clippers  1,600,000,000.00   $2,000,000,000.00
# 5             Nets  1,500,000,000.00   $1,900,000,000.00
# 6         Warriors  1,300,000,000.00   $1,700,000,000.00
# 7          Rockets  1,250,000,000.00   $1,500,000,000.00
# 8             Heat  1,175,000,000.00   $1,400,000,000.00
# 9        Mavericks  1,150,000,000.00   $1,300,000,000.00
# 10           Spurs  1,000,000,000.00   $1,150,000,000.00
# 11   Trail Blazers    940,000,000.00   $1,100,000,000.00
# 12         Thunder    930,000,000.00   $1,000,000,000.00
# 13         Raptors    920,000,000.00     $980,000,000.00
# 14       Cavaliers    915,000,000.00     $975,000,000.00
# ...

# %%
top_teams = renamed_file_one_df.head(5)

bottom_teams_df = renamed_file_one_df.sort_values(by=["2019"], ascending=True)
reset_bottom_teams_df = bottom_teams_df.reset_index()
lowest_teams = reset_bottom_teams_df.drop(columns=["index"])

lowest_teams.head(5)
# Out:
#             Team            2015               2016               2017  \
# 0          Bucks  600,000,000.00   $650,000,000.00    $750,000,000.00
# 1   Timberwolves  625,000,000.00   $675,000,000.00    $770,000,000.00
# 2       Pelicans  650,000,000.00   $700,000,000.00    $780,000,000.00
# 3          76ers  700,000,000.00   $720,000,000.00    $785,000,000.00
# 4        Hornets  725,000,000.00   $750,000,000.00    $790,000,000.00
#
#                   2018               2019
# 0   $1,000,000,000.00   $1,200,000,000.00
# 1   $1,025,000,000.00   $1,220,000,000.00
# 2   $1,050,000,000.00   $1,250,000,000.00
# 3   $1,060,000,000.00   $1,260,000,000.00
# 4   $1,075,000,000.00   $1,270,000,000.00

# %%
teams = ["Lakers", "Knicks", "Bulls", "Celtics", "Clippers"]
x_axis = np.arange(len(teams))
plt.bar(x_axis, teams, color='r', alpha=0.5, align="center")
# Out:
# <BarContainer object of 5 artists>
